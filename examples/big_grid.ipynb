# %%
from am4894pd.utils import df_dummy_ts # used to generate some dummy data
from am4894plots.plots import plot_lines, plot_lines_grid
from am4894plots.lines.bokeh import plot_lines as plot_lines_bokeh
from am4894plots.lines.bokeh import plot_lines_grid as plot_lines_grid_bk

# generate some dummy time series data
df = df_dummy_ts(n_cols=100, freq='1min')
print(df.shape)
display(df.head())
# Out:
# (1342, 100)
#                          col0      col1      col2      col3      col4  \
# time
# 2019-01-01 01:39:00 -0.092016  0.039975  0.102447  0.018053  0.019972
# 2019-01-01 01:40:00 -0.088947  0.025071  0.105526  0.051649  0.011258
# 2019-01-01 01:41:00 -0.093152  0.037621  0.121816  0.079790  0.004748
# 2019-01-01 01:42:00 -0.126350  0.059000  0.110249  0.082383  0.005394
# 2019-01-01 01:43:00 -0.110099  0.080874  0.111436  0.060216  0.014019
#
#                          col5      col6      col7      col8      col9  ...  \
# time                                                                   ...
# 2019-01-01 01:39:00 -0.093149  0.051805  0.100195  0.058038  0.088159  ...
# 2019-01-01 01:40:00 -0.083713  0.056416  0.117870  0.045627  0.114506  ...
# 2019-01-01 01:41:00 -0.070478  0.051631  0.123667  0.036154  0.115582  ...
# 2019-01-01 01:42:00 -0.060776  0.055147  0.130225  0.041119  0.144315  ...
# 2019-01-01 01:43:00 -0.043162  0.057866  0.126415  0.040999  0.148333  ...
#
#                         col90     col91     col92     col93     col94  \
# time
# 2019-01-01 01:39:00 -0.079638 -0.276853  0.146054  0.107363  0.025321
# 2019-01-01 01:40:00 -0.080292 -0.245150  0.136578  0.087053  0.011791
# 2019-01-01 01:41:00 -0.069590 -0.235045  0.120597  0.093298  0.008179
# 2019-01-01 01:42:00 -0.076551 -0.238412  0.120693  0.080612  0.012718
# 2019-01-01 01:43:00 -0.070542 -0.234889  0.107734  0.084547  0.014416
#
#                         col95     col96     col97     col98     col99
# time
# 2019-01-01 01:39:00 -0.068099 -0.064964 -0.075467 -0.004731  0.038347
# 2019-01-01 01:40:00 -0.050581 -0.048708 -0.081600  0.030864  0.047549
# 2019-01-01 01:41:00 -0.053039 -0.072586 -0.082284  0.015509  0.033691
# 2019-01-01 01:42:00 -0.028378 -0.085154 -0.085144  0.035979  0.028074
# 2019-01-01 01:43:00 -0.002964 -0.067761 -0.079532  0.038041  0.007594
#
# [5 rows x 100 columns]

# %%
# make shaded region
shade_regions = [(df.index[-100:].min(), df.index.max()), 'grey']
print(shade_regions)
# Out:
# [(Timestamp('2019-01-01 22:21:00'), Timestamp('2019-01-02 00:00:00')), 'grey']

# %%
# plot each time series on single plot as a line
plot_lines_grid(
    df, return_p=False, show_p=False, out_path='dev/dev.html', h_each=100, w=1200, legend=False, yaxes_visible=False,
    shade_regions=shade_regions
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-074719739d38> in <module>
#       1 # plot each time series on single plot as a line
# ----> 2 plot_lines_grid(
#       3     df, return_p=False, show_p=False, out_path='dev/dev.html', h_each=100, w=1200, legend=False, yaxes_visible=False,
#       4     shade_regions=shade_regions
#       5 )
#
# ~\Documents\repos\am4894plots\am4894plots\lines\plotly.py in plot_lines_grid(df, cols, cols_like, x, title, slider, out_path, show_p, return_p, h, w, vertical_spacing, theme, lw, renderer, shade_regions, shade_color, shade_opacity, shade_line_width, marker_list, marker_mode, marker_position, marker_color, marker_size, marker_symbol, h_each, legend, yaxes_visible)
#     150     if shade_regions:
#     151         shapes_to_add = []
# --> 152         for x_from, x_to in shade_regions:
#     153             # check if region is in the data to be plotted and only plot if is
#     154             if x_from >= x.min() and x_to <= x.max():
#
# ValueError: too many values to unpack (expected 2)

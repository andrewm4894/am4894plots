# %%
from am4894pd.utils import df_dummy_ts # used to generate some dummy data
from am4894plots.plots import plot_lines, plot_lines_grid
from am4894plots.lines.bokeh import plot_lines as plot_lines_bokeh
from am4894plots.lines.bokeh import plot_lines_grid as plot_lines_grid_bk

# generate some dummy time series data
df = df_dummy_ts(n_cols=50, freq='1min')
print(df.shape)
display(df.head())
# Out:
# (1342, 50)
#                          col0      col1      col2      col3      col4  \
# time
# 2019-01-01 01:39:00 -0.143101  0.129735 -0.041885 -0.270516 -0.085860
# 2019-01-01 01:40:00 -0.136032  0.142905 -0.037119 -0.267766 -0.102074
# 2019-01-01 01:41:00 -0.127910  0.108176 -0.050772 -0.253523 -0.110302
# 2019-01-01 01:42:00 -0.122366  0.093790 -0.068986 -0.229688 -0.091021
# 2019-01-01 01:43:00 -0.102159  0.075034 -0.070881 -0.239402 -0.082919
#
#                          col5      col6      col7      col8      col9  ...  \
# time                                                                   ...
# 2019-01-01 01:39:00 -0.141922 -0.077211  0.035053  0.043910  0.023560  ...
# 2019-01-01 01:40:00 -0.143620 -0.055589  0.034758  0.043198  0.009526  ...
# 2019-01-01 01:41:00 -0.152690 -0.052178  0.040251  0.028183  0.029858  ...
# 2019-01-01 01:42:00 -0.128455 -0.060090  0.027638  0.013584  0.029993  ...
# 2019-01-01 01:43:00 -0.116266 -0.072523  0.032829  0.017640  0.024705  ...
#
#                         col40     col41     col42     col43     col44  \
# time
# 2019-01-01 01:39:00  0.028274  0.010074  0.142755 -0.016898 -0.067829
# 2019-01-01 01:40:00  0.048328  0.014812  0.137792  0.006488 -0.046864
# 2019-01-01 01:41:00  0.046991  0.020098  0.145402  0.001782 -0.054868
# 2019-01-01 01:42:00  0.060538  0.038647  0.127253 -0.009628 -0.052920
# 2019-01-01 01:43:00  0.066041  0.015804  0.116343 -0.023167 -0.049634
#
#                         col45     col46     col47     col48     col49
# time
# 2019-01-01 01:39:00 -0.055334  0.092735 -0.112810 -0.013537 -0.006475
# 2019-01-01 01:40:00 -0.048617  0.080618 -0.104861 -0.017007  0.022781
# 2019-01-01 01:41:00 -0.030311  0.067986 -0.097402 -0.007896  0.029613
# 2019-01-01 01:42:00 -0.021406  0.063176 -0.122311  0.015692  0.047055
# 2019-01-01 01:43:00 -0.019831  0.044814 -0.115636  0.001311  0.028749
#
# [5 rows x 50 columns]

# %%
# plot each time series on single plot as a line
plot_lines_grid(df, return_p=False, show_p=False, out_path='dev/dev.html', h_each=100, w=1200, legend=False)
